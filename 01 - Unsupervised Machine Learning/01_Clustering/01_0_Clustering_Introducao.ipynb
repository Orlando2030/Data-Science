# %% [markdown]
# # 🎯 1. O que é Clustering?
#
# Clusterização é uma técnica de agrupamento usada quando você NÃO sabe previamente quais grupos existem nos dados.
#
# É como separar roupas sujas automaticamente sem olhar as etiquetas — a máquina tenta descobrir sozinha quais peças são parecidas.
#
# ✔ Objetivo:
#
# 	•	Dentro do grupo: tudo bem parecido
#
# 	•	Entre grupos: tudo bem diferente
#
# 📌 Ex.: Separar clientes em grupos com comportamentos parecidos.
#
#
# # 🛒 2. Onde isso é usado?
#
# Imagine que você quer separar pessoas ou coisas por similaridade:
#
# 	•	Marketing → grupos de clientes parecidos
#
# 	•	Saúde → grupos de pacientes com perfis semelhantes
#
# 	•	Fraude → achar transações “diferentonas”
#
# 	•	Produtos → separar itens que têm defeitos parecidos
#
# 📌 Analogia: como organizar suas playlists automaticamente por “vibe” das músicas.
#
# # 🧭 3. Por que é “não supervisionado”?
#
# Porque você não diz ao algoritmo qual é o grupo certo.
#
# Ele tenta descobrir padrões sozinho.
#
# 📌 Analogia: É como separar fotos do celular por “rostos parecidos” sem informar quem é quem.

# %% [markdown]
# # 4. Cluster Hierárquico vs 🔶 Cluster Não Hierárquico
#
# ## 🧱 4.1. Cluster Hierárquico
#
# 📌 O que é: Cria uma árvore de agrupamentos (dendrograma), mostrando como os dados vão se juntando ou se separando em níveis.
#
# 	### 🔍 Como funciona:
#
# 		Existem dois tipos principais:
#
# 		🔹 Aglomerativo (mais comum)
#
# 			•	Cada ponto começa sozinho
#
# 			•	Vai juntando os mais parecidos
#
# 			•	Forma uma árvore até virar um único grupo
#
# 		🔹 Divisivo
#
# 			•	Começa com todos juntos
#
# 			•	Vai dividindo em grupos menores
#
# 	### 🎯 Principais características:
#
# 			✔ Não precisa definir o número de clusters antes
#
# 			✔ Gera uma visualização clara (dendrograma)
#
# 			✔ Ótimo para entender a estrutura dos dados
#
# 			❌ Mais lento em bases grandes
#
# 			❌ Pouco escalável
#
# 	### 🧠 Quando usar:
#
# 			•	Exploração inicial dos dados
#
# 			•	Bases pequenas ou médias
#
# 			•	Quando você quer entender relações entre grupos
#
# 			•	Análise científica, biológica, social

# %% [markdown]
# ## 🔶 4.2. Cluster Não Hierárquico
#
# ### 📌 O que é:
#
# 		Agrupa os dados diretamente em K grupos, sem criar uma estrutura em árvore.
#
# ### 🔍 Exemplo mais famoso:
#
# 		- 👉 K-Means
#
# ### 🎯 Principais características:
#
# 		✔ Muito rápido e escalável
#
# 		✔ Ideal para grandes volumes de dados
#
# 		✔ Fácil de implementar
#
# 		❌ Precisa definir o número de clusters antes
#
# 		❌ Sensível à inicialização
#
# 		❌ Não mostra hierarquia
#
# ### 🧠 Quando usar:
#
# 		•	Grandes bases de dados
#
# 		•	Produção e sistemas reais
#
# 		•	Segmentação de clientes, mercado, comportamento
#
# 		•	Machine Learning aplicado
