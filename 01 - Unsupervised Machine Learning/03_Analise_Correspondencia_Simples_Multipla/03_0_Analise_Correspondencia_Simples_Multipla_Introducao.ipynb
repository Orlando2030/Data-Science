# %% [markdown]
# # 📊 Análise de Correspondência (AC)
#
#     É uma técnica de Análise Multivariada usada para explorar relações entre variáveis categóricas, baseada em tabelas de contingência.
#
#     Ela transforma categorias em pontos num plano cartesiano, facilitando a visualização das associações.
#
#
# ## 🔹 Análise de Correspondência Simples (ACS)
#
# ### O que é
#
#     Aplica-se quando você tem duas variáveis categóricas.
#
#
#
# ### Serve para
#
#
#     Visualizar a associação entre as categorias de duas variáveis.
#
#
# ### Exemplo
#
#
#     Sexo × Preferência de produto
#
#     → mostra quais categorias estão associadas no mapa.
#
#
#
# ## 🔹 Análise de Correspondência Múltipla (ACM)
#
#
# ### O que é
#
#
#     Extensão da ACS para mais de duas variáveis categóricas.
#
#
# ## Serve para
#
#
#     Analisar simultaneamente várias variáveis categóricas e identificar perfis.
#
#
# ### Exemplo
#
#
# Sexo, Escolaridade, Renda, Região
# → revela perfis de consumidores.
#
#
# ## 🧭 Diferença rápida
#
# #### ACS ---------------------||----ACM
#
# Duas variáveis categóricas------||----Várias variáveis categóricas
#
# Base em uma tabela ------------||----Base em várias variáveis
#
# Associação simples -------------||----Perfis e segmentações

# %% [markdown]
# ## 🎯 Quando usar
#
# #### Use AC quando:
#     ✔️ Seus dados são categóricos
#
#     ✔️ Você quer entender associações
#
#     ✔️ Quer visualizar relações de forma gráfica
#
#
# ## 🧠 Frase para memorizar
#
#     🔹 ACS compara duas variáveis categóricas.
#
#     🔹 ACM analisa várias variáveis categóricas ao mesmo tempo.
