# %% [markdown]
# ### PCA — transforma COLUNAS em componentes matemáticos
#
# 		👉 Aqui o foco são as variáveis, não as pessoas.
#
#
# 📌 O que ele faz?
#
# Ele pega muitas colunas correlacionadas e cria novas colunas resumidas, chamadas componentes principais.
#
#
#
# 🧠 Exemplo real
#
# Você tem estas colunas:
#
# 		•	Altura
#
# 		•	Peso
#
# 		•	IMC
#
# 		•	% Gordura
#
# O PCA cria:
#
# 		•	Componente 1 → “Tamanho físico”
#
# 		•	Componente 2 → “Composição corporal”
#
#
# Esses componentes são combinações matemáticas das colunas originais.
#
# 		👉 Ele não cria grupos, ele cria novas colunas.
#
# Visualmente:
#
# Antes:
# __________________________________
# | Autura | Peso | IMC | %Gordura |
# __________________________________
#
# Depois:
# _____________________________
# | Componete 1 | Componete 2 |
# _____________________________
#
# ### Análise Fatorial — transforma COLUNAS em fatores conceituais
#
# É parecida com o PCA, mas com um objetivo diferente.
#
#
# 📌 O que ela faz?
# 	Ela tenta descobrir conceitos ocultos que explicam várias colunas ao mesmo tempo.
#
#
#
# 🧠 Exemplo real
# Você tem um questionário com perguntas como:
#
# 		•	Gosto do meu chefe
#
# 		•	Sinto-me valorizado
#
# 		•	Recebo feedbacks
#
# 		•	O salário é justo
#
# A Análise Fatorial descobre:
#
# 		•	Fator 1: “Satisfação com liderança”
#
# 		•	Fator 2: “Reconhecimento profissional”
#
# 		👉 Esses fatores não existem na tabela original, são conceitos abstratos.
#
# Diferença importante:
#
# 		•	PCA → foco matemático e redução de dados
#
# 		•	Fatorial → foco interpretável e conceitual
